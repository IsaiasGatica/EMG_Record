# %%
from Funciones import*

# %%
import pandas as pd

archivo_csv = 'CaracteristicasCSV/caracteristicasV18.csv'  
caracteristicas_df = pd.read_csv(archivo_csv)

# %%
# MAV,STD,RMS,VAR,WL,DMAV,SSC,Entropy,MeanD

Estadistico = 'SSC' 

grafico_caracteristicas(caracteristicas_df,Estadistico)

Estadistico = 'WL'  

grafico_caracteristicas(caracteristicas_df,Estadistico)

Estadistico = 'WL'  

grafico_caracteristicas(caracteristicas_df,Estadistico)

# %%
import pandas as pd
import plotly.express as px

# Lista de valores
valores = [2.61739521e+02, 2.73589688e+02, 2.91920001e+02, 1.47766969e+02,
           1.91171692e+02, 4.05305067e+02, 4.34440774e+02, 3.92218707e+00,
           2.70964659e-01]

# Datos para valor1
valores1 = [21.21995133, 23.20041194, 23.57783295, 21.00503339, 26.55778012, 21.78714283, 9.20522491, 1.10394344, 0.76029002]

# Datos para valor2
valores2 = [24.49697593, 23.04763013, 23.64540287, 15.38500961, 15.01900872, 30.7401869, 65.2107842, 0.86491041, 2.09560347]


# Nombres de las características
caracteristicas = ['MAV', 'STD', 'RMS', 'VAR', 'WL', 'DMAV', 'SSC', 'Entropy', 'MeanD']

# Crea un DataFrame
df_anular = pd.DataFrame({'Caracteristicas': caracteristicas, 'Valores': valores})
df_indice = pd.DataFrame({'Caracteristicas': caracteristicas, 'Valores': valores1})
df_medio = pd.DataFrame({'Caracteristicas': caracteristicas, 'Valores': valores2})

# Crea el gráfico de barras con Plotly Express
fig = px.bar(df_anular, x='Caracteristicas', y='Valores', title='Gráfico de Barras',template="plotly_dark")
fig["data"][0]["showlegend"] = True
fig["data"][0]["name"] = "Anular"
fig.add_bar(x=df_medio['Caracteristicas'], y=df_medio['Valores'], name='Medio', opacity=0.4)

fig.add_bar(x=df_indice['Caracteristicas'], y=df_indice['Valores'], name='Indice', opacity=0.4)




# Muestra el gráfico
fig.show()
